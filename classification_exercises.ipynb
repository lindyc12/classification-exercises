# %%
from math import sqrt
from scipy import stats

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pydataset import data
import statistics
import seaborn as sns

# %%
from pydataset import data
df = data("iris")
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
#print the first 3 rows

df.head(3)
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
#print the number of rows and columns (shape)

df.shape
# Out:
# (150, 5)

# %%
#print the column names
df.columns
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width',
#        'Species'],
#       dtype='object')

# %%
# print the data type of each column

df.dtypes
# Out:
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
# print the summary statistics for each of the numeric variables

df.describe()
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# 5

sheet_url = 'https://docs.google.com/spreadsheets/d/19w21wz3gnjtHUwPX-hOZNf9sEIExmVT4rPlIk1Pqp50/edit#gid=1023018493'    

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

# %%
df_google_sheet = pd.read_csv(csv_export_url)
df_google_sheet.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                  0     Yes        Yes              1
# 1  0003-MKNFE    Male                  0      No         No              2
# 2  0004-TLHLJ    Male                  0      No         No              1
# 3  0011-IGKFF    Male                  1     Yes         No              1
# 4  0013-EXCHZ  Female                  1     Yes         No              1
#
#    internet_service  contract_type      payment_type  monthly_charges  \
# 0                 1              1      Mailed check             65.6
# 1                 1              0      Mailed check             59.9
# 2                 2              0  Electronic check             73.9
# 3                 2              0  Electronic check             98.0
# 4                 2              0      Mailed check             83.9
#
#    total_charges churn  tenure
# 0         593.30    No     9.0
# ...

# %%
# assign the first 100 rows to a new dataframe, df_google_sheets_sample

df_google_sheets_sample = df_googlesheet.head(100)

# %%
df_google_sheets_sample.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                  0     Yes        Yes              1
# 1  0003-MKNFE    Male                  0      No         No              2
# 2  0004-TLHLJ    Male                  0      No         No              1
# 3  0011-IGKFF    Male                  1     Yes         No              1
# 4  0013-EXCHZ  Female                  1     Yes         No              1
#
#    internet_service  contract_type      payment_type  monthly_charges  \
# 0                 1              1      Mailed check             65.6
# 1                 1              0      Mailed check             59.9
# 2                 2              0  Electronic check             73.9
# 3                 2              0  Electronic check             98.0
# 4                 2              0      Mailed check             83.9
#
#    total_charges churn  tenure
# 0         593.30    No     9.0
# ...

# %%
df_go

# %%
#print the number of rows of your original dataframe

len(df_google_sheet)
# Out:
# 7049

# %%
# print the first 5 column names

print(df_google_sheets_sample.columns)
# Out:
# Index(['customer_id', 'gender', 'is_senior_citizen', 'partner', 'dependents',
#        'phone_service', 'internet_service', 'contract_type', 'payment_type',
#        'monthly_charges', 'total_charges', 'churn', 'tenure'],
#       dtype='object')

# %%
# print the column names that have a data type of object

df_google_sheets_sample.select_dtypes('O')
# Out:
#    customer_id  gender partner dependents               payment_type churn
# 0   0002-ORFBO  Female     Yes        Yes               Mailed check    No
# 1   0003-MKNFE    Male      No         No               Mailed check    No
# 2   0004-TLHLJ    Male      No         No           Electronic check   Yes
# 3   0011-IGKFF    Male     Yes         No           Electronic check   Yes
# 4   0013-EXCHZ  Female     Yes         No               Mailed check   Yes
# 5   0013-MHZWF  Female      No        Yes    Credit card (automatic)    No
# 6   0013-SMEOE  Female     Yes         No  Bank transfer (automatic)    No
# 7   0014-BMAQU    Male     Yes         No    Credit card (automatic)    No
# 8   0015-UOCOJ  Female      No         No           Electronic check    No
# 9   0016-QLJIS  Female     Yes        Yes               Mailed check    No
# 10  0017-DINOC    Male      No         No    Credit card (automatic)    No
# ...

# %%
# compute the range for each of the numeric variables.

df_google_sheet

# %%
# 6


df_excel = pd.read_clipboard()
df_excel
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                0.0     Yes        Yes            1.0
# 1     0003-MKNFE    Male                0.0      No         No            2.0
# 2     0004-TLHLJ    Male                0.0      No         No            1.0
# 3     0011-IGKFF    Male                1.0     Yes         No            1.0
# 4     0013-EXCHZ  Female                1.0     Yes         No            1.0
# ...          ...     ...                ...     ...        ...            ...
# 7045  9992-RRAMN    Male                0.0     Yes         No            2.0
# 7046  9992-UJOEL    Male                0.0      No         No            1.0
# 7047  9993-LHIEB    Male                0.0     Yes        Yes            1.0
# 7048  9995-HOTOH    Male                0.0     Yes        Yes            0.0
# 7049         NaN     NaN                NaN     NaN        NaN            NaN
#
# ...

# %%
df_excel.head(3)
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                0.0     Yes        Yes            1.0
# 1  0003-MKNFE    Male                0.0      No         No            2.0
# 2  0004-TLHLJ    Male                0.0      No         No            1.0
#
#    internet_service  contract_type      payment_type  monthly_charges  ...  \
# 0               1.0            1.0      Mailed check             65.6  ...
# 1               1.0            0.0      Mailed check             59.9  ...
# 2               2.0            0.0  Electronic check             73.9  ...
#
#    has_phone has_internet  has_phone_and_internet partner_depends  \
# 0       True         True                    True             3.0
# 1       True         True                    True             0.0
# 2       True         True                    True             0.0
#
#   cal_monthly_charges validate     phone_services int_type  rounded  \
# ...

# %%
df_excel.dtypes
# Out:
# customer_id                object
# gender                     object
# is_senior_citizen         float64
# partner                    object
# dependents                 object
# phone_service             float64
# internet_service          float64
# contract_type             float64
# payment_type               object
# monthly_charges           float64
# total_charges             float64
# churn                      object
# tenure                    float64
# is_female                  object
# has_churned                object
# has_phone                  object
# has_internet               object
# has_phone_and_internet     object
# partner_depends           float64
# cal_monthly_charges        object
# validate                  float64
# phone_services             object
# int_type                   object
# rounded                   float64
# service_type               object
# dtype: object

# %%
# assign the first 100 rows to a new dataframe

df_excel_sample = df_excel.head(100)

# %%
df_excel_sample.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                0.0     Yes        Yes            1.0
# 1  0003-MKNFE    Male                0.0      No         No            2.0
# 2  0004-TLHLJ    Male                0.0      No         No            1.0
# 3  0011-IGKFF    Male                1.0     Yes         No            1.0
# 4  0013-EXCHZ  Female                1.0     Yes         No            1.0
#
#    internet_service  contract_type      payment_type  monthly_charges  \
# 0               1.0            1.0      Mailed check             65.6
# 1               1.0            0.0      Mailed check             59.9
# 2               2.0            0.0  Electronic check             73.9
# 3               2.0            0.0  Electronic check             98.0
# 4               2.0            0.0      Mailed check             83.9
#
#    total_charges churn  tenure  Unnamed: 13
# 0         593.30    No     9.0          NaN
# ...

# %%
# print the number of rows of your original dataframe

len(df_excel)
# Out:
# 7050

# %%
# print the first 5 column names

N = 5

first_n_column  = df_excel_sample.iloc[: , :N]

# %%
first_n_column
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width     Species
# 1             5.1          3.5           1.4          0.2      setosa
# 2             4.9          3.0           1.4          0.2      setosa
# 3             4.7          3.2           1.3          0.2      setosa
# 4             4.6          3.1           1.5          0.2      setosa
# 5             5.0          3.6           1.4          0.2      setosa
# 6             5.4          3.9           1.7          0.4      setosa
# 7             4.6          3.4           1.4          0.3      setosa
# 8             5.0          3.4           1.5          0.2      setosa
# 9             4.4          2.9           1.4          0.2      setosa
# 10            4.9          3.1           1.5          0.1      setosa
# 11            5.4          3.7           1.5          0.2      setosa
# 12            4.8          3.4           1.6          0.2      setosa
# ...

# %%
# print the column names that have a data type of object

df_excel_sample.select_dtypes('O')
# Out:
#         Species
# 1        setosa
# 2        setosa
# 3        setosa
# 4        setosa
# 5        setosa
# 6        setosa
# 7        setosa
# 8        setosa
# 9        setosa
# 10       setosa
# 11       setosa
# 12       setosa
# 13       setosa
# 14       setosa
# 15       setosa
# 16       setosa
# 17       setosa
# 18       setosa
# 19       setosa
# 20       setosa
# 21       setosa
# 22       setosa
# 23       setosa
# 24       setosa
# 25       setosa
# 26       setosa
# 27       setosa
# 28       setosa
# 29       setosa
# 30       setosa
# 31       setosa
# 32       setosa
# 33       setosa
# 34       setosa
# 35       setosa
# 36       setosa
# 37       setosa
# 38       setosa
# 39       setosa
# 40       setosa
# 41       setosa
# 42       setosa
# 43       setosa
# 44       setosa
# 45       setosa
# 46       setosa
# 47       setosa
# 48       setosa
# 49       setosa
# 50       setosa
# 51   versicolor
# 52   versicolor
# 53   versicolor
# 54   versicolor
# ...

# %%
# compute the range for each of the numeric variables.

# %%
# 7

df_google = pd.read_clipboard()
df_google
# Out:
#      PassengerId  Survived  Pclass  \
# 0            1.0       0.0     3.0
# 1            2.0       1.0     1.0
# 2            3.0       1.0     3.0
# 3            4.0       1.0     1.0
# 4            5.0       0.0     3.0
# ..           ...       ...     ...
# 994          NaN       NaN     NaN
# 995          NaN       NaN     NaN
# 996          NaN       NaN     NaN
# 997          NaN       NaN     NaN
# 998          NaN       NaN     NaN
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0    1.0
# 2                                 Heikkinen, Miss. Laina  female  26.0    0.0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                               Allen, Mr. William Henry    male  35.0    0.0
# ...

# %%
df_google.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          1.0       0.0     3.0
# 1          2.0       1.0     1.0
# 2          3.0       1.0     3.0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
#
#    Parch            Ticket     Fare  ... Unnamed: 16 Unnamed: 17  Unnamed: 18  \
# 0    0.0         A/5 21171   7.2500  ...         NaN         NaN          NaN
# 1    0.0          PC 17599  71.2833  ...         NaN         NaN          NaN
# 2    0.0  STON/O2. 3101282   7.9250  ...         NaN         NaN          NaN
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# ...

# %%
df_google.shape
# Out:
# (999, 26)

# %%
df_google.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='object')
